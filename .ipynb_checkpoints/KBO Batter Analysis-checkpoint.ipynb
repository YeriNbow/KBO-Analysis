# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sc
import seaborn as sns
import re

# %%
# 한글 출력
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
팀 상황 알아보기(삼성 라이온즈)

# %%
df = pd.read_excel(r'D:\IT\mywork\Project\KBO-Analysis\dataset\kbo_team.xlsx', encoding='utf-8', index=False)
df.Season = df.Season.apply(lambda x: x+2000 if x<82 else x+1900)
samsung = df[df.Team == '삼성'].reset_index(drop=True)
samsung.head()
# Out:
#   Team  Season    WAR     G    PA    AB    R     H   2B  3B  ...  DP  SH  SF  \
# 0   삼성    1982  18.61   887  3043  2647  429   705  126  18  ...  50  36  18
# 1   삼성    1983  23.31  1249  3847  3383  448   889  143  14  ...  62  66  27
# 2   삼성    1984  24.07  1262  3756  3298  435   889  147  18  ...  62  62  18
# 3   삼성    1985  29.97  1513  4250  3644  552  1005  181  22  ...  74  93  42
# 4   삼성    1986  30.54  1527  4119  3617  475   997  177  22  ...  76  68  31
#
#      AVG    OBP    SLG    OPS   wOBA   WRC+  Rank
# 0  0.266  0.347  0.392  0.739  0.338  104.3     2
# 1  0.263  0.333  0.393  0.726  0.332  110.3     1
# 2  0.270  0.343  0.396  0.739  0.339  113.9     1
# 3  0.276  0.355  0.417  0.772  0.351  117.9     1
# 4  0.276  0.345  0.398  0.744  0.346  123.2     1
#
# [5 rows x 29 columns]

# %%
plt.figure(figsize=(20, 7))
plt.plot(samsung.Season, samsung['WRC+'])
plt.axhline(y=100, color='r', linewidth=2)
plt.xticks(samsung.Season)
plt.show()

# %%
삼성 라이온즈 역사상 WRC+가 평균인 100 이하로 떨어진 적은 크게 많지 않음.
항상 평균 이상의 생산성을 보였던 팀이고 2000년대 초반의 침체기 때도 2007년을 제외하고는 평균적인 수준은 유지했음.

# %%
years = [2007, 2011, 2016, 2017, 2018, 2019, 2020]
compare = pd.DataFrame()

for year in years:
    s = samsung[samsung.Season == year]
    compare = pd.concat([compare, s[['Season', 'WRC+', 'WAR', 'AVG', 'OBP', 'SLG', 'OPS', 'wOBA']]])

compare.reset_index(inplace=True, drop=True)
compare
# Out:
#    Season   WRC+    WAR    AVG    OBP    SLG    OPS   wOBA
# 0    2007   97.0  20.97  0.254  0.341  0.365  0.706  0.326
# 1    2011   98.9  25.18  0.259  0.343  0.376  0.719  0.334
# 2    2016  100.1  22.21  0.293  0.367  0.439  0.806  0.360
# 3    2017   92.7  16.82  0.279  0.340  0.428  0.768  0.337
# 4    2018   96.6  19.89  0.288  0.355  0.432  0.787  0.344
# 5    2019   94.7  17.45  0.256  0.329  0.389  0.718  0.328
# 6    2020   90.5  15.66  0.268  0.338  0.394  0.732  0.333

# %%
plt.figure(figsize=(20, 7))
plt.plot(compare.Season, compare['WRC+'], marker='o')
plt.axhline(y=97, color='r', linewidth=2)

plt.text(2007, 96.5, '4', fontsize=15)
plt.text(2011, 98.4, '왕조시작', fontsize=15)
plt.text(2016.2, 99.5, '왕조몰락', fontsize=15)
plt.text(2017, 92, '9', fontsize=15)
plt.text(2018.1, 96.4, '6', fontsize=15)
plt.text(2019.2, 94.2, '8', fontsize=15)
plt.text(2020.2, 90.2, '8', fontsize=15)

plt.xticks(compare.Season)
plt.show()

# %%
하지만, FA로 팀의 클린업을 담당하던 주요 타자들이 이탈한 2016년을 기점으로, 삼성 타자들의 WRC+는 2007년의 소위 '삼점 라이온즈' 시절
이하로 급격하게 추락함. 암흑기 동안 기록하고 있는 100 이하의 WRC+는 평균 대비 -의 생산력을 의미하는 것으로 타자들이 타석에
들어서도 평균보다 점수를 못낸다는 것을 의미함.

다만, 팀 타선의 생산성이 2007년 수준으로 살짝 반등했었던 2018년에 팀이 마지막까지 가을 야구를 경쟁했었다는 것을 생각해보면, 
삼성 라이온즈는 타선만 뒷받침 된다면 충분히 재도약이 가능할 것으로 보임. 하지만 2018년의 반등이 이어지지 못하고 올해 팀 역사상
최악의 WRC+인 90.5를 기록했다는 것은 어떤 방식으로든 타석에서 점수를 내줄 수 있는 확실한 타자가 없다는 것을 의미함.

즉, 게임처럼 갑자기 유망주들의 잠재력이 폭발해서 리그를 지배하는 것이 아닌 이상, 역대 최악의 변비타선을 해결하기 위해서는
FA영입을 통한 타선 보강이 절실해 보임. 그렇다면 2021년 FA 명단 중 누구를 영입해야할까?

# %%
df = pd.read_excel(r'D:\IT\mywork\Project\KBO-Analysis\dataset\kbo_batter2.xlsx', encoding='utf-8', index=False)

df.Season = df.Season.apply(lambda x: x+2000 if x<82 else x+1900)
df['Birth'] = pd.to_datetime(df['Birth'], format='%Y-%m-%d')
df['Age'] = df.Season - df.Birth.dt.year

df.head()
# Out:
#   Name  Season      Birth Team Position   WAR   G   PA   AB   R  ...  DP  SH  \
# 0  백인천    1982 1943-11-27    M       DH  5.88  72  298  250  55  ...   5   0
# 1  윤동균    1982 1949-07-02    O       LF  4.13  77  334  284  54  ...   3   0
# 2  이만수    1982 1958-09-19    삼        C  4.12  78  322  270  46  ...  13   0
# 3  김봉연    1982 1952-01-13    해       DH  3.68  74  304  269  55  ...   8   0
# 4  김우열    1982 1949-09-09    O       CF  3.46  62  255  210  43  ...   0   0
#
#    SF    AVG    OBP    SLG    OPS   wOBA   WRC+  Age
# 0   3  0.412  0.497  0.740  1.237  0.528  227.0   39
# 1   4  0.342  0.428  0.532  0.960  0.430  164.6   33
# 2   1  0.289  0.399  0.500  0.899  0.405  147.6   24
# 3   1  0.331  0.405  0.636  1.040  0.453  180.5   30
# 4   1  0.310  0.428  0.533  0.961  0.426  161.9   33
#
# [5 rows x 32 columns]

# %%
df.corr()['WRC+'].sort_values(ascending=False).head(6)
# Out:
# WRC+    1.000000
# wOBA    0.993386
# OPS     0.980681
# OBP     0.946236
# SLG     0.925187
# AVG     0.904526
# Name: WRC+, dtype: float64

# %%
WRC+와 상관관계가 높은 지표들은 타/출/장/OPS/wOBA

# %%
columns = ['Name', 'Season', 'Position', 'Age', 'PA', 'AVG','OBP','SLG','OPS','wOBA','WRC+']

# %%
samsung = df[(df.Team == '삼') & (df.Season == 2020)][columns]
samsung.reset_index(inplace=True, drop=True)
samsung
# Out:
#     Name  Season Position  Age   PA    AVG    OBP    SLG    OPS   wOBA   WRC+
# 0    구자욱    2020       LF   27  510  0.307  0.385  0.478  0.863  0.387  125.9
# 1    김상수    2020       2B   30  471  0.304  0.397  0.401  0.798  0.372  118.1
# 2    강민호    2020        C   35  393  0.287  0.349  0.487  0.836  0.370  112.5
# 3    박해민    2020       CF   30  541  0.290  0.345  0.415  0.760  0.342   97.8
# 4    김동엽    2020       DH   30  451  0.312  0.360  0.508  0.869  0.385  122.8
# 5   살라디노    2020       LF   31  163  0.280  0.411  0.477  0.888  0.405  136.3
# 6    이원석    2020       3B   34  467  0.268  0.341  0.407  0.748  0.338   93.7
# 7    김호재    2020       3B   25  138  0.322  0.416  0.390  0.806  0.381  124.0
# 8    강한울    2020       SS   29  122  0.305  0.368  0.362  0.729  0.330   90.8
# 9    최영진    2020       3B   32  118  0.297  0.385  0.356  0.741  0.351  104.0
# 10   이학주    2020       SS   30  243  0.228  0.314  0.340  0.654  0.298   67.9
# 11   이성곤    2020       1B   28  154  0.281  0.329  0.439  0.768  0.340   94.5
# 12   김지찬    2020       2B   19  287  0.232  0.301  0.272  0.573  0.272   53.2
# 13   송준석    2020       RF   26   50  0.277  0.320  0.447  0.767  0.345   97.7
# 14   김성윤    2020       LF   21    9  0.286  0.444  0.429  0.873  0.414  144.4
# 15   권정웅    2020        C   28    2  0.000  0.500  0.000  0.500  0.367  112.8
# 16   김재현    2020       SS   29   18  0.143  0.294  0.143  0.437  0.227   23.1
# 17   김도환    2020        C   20   49  0.220  0.292  0.268  0.560  0.262   46.4
# 18   김성표    2020       CF   26    8  0.125  0.125  0.125  0.250  0.118  -47.9
# 19   김민수    2020        C   29   26  0.174  0.240  0.174  0.414  0.201    6.9
# 20   백승민    2020       1B   30   12  0.000  0.250  0.000  0.250  0.188   -4.6
# 21   박찬도    2020       LF   31  116  0.219  0.325  0.302  0.627  0.292   64.6
# 22   김응민    2020        C   29   85  0.224  0.281  0.237  0.517  0.245   35.4
# 23   양우현    2020       2B   20   24  0.130  0.167  0.130  0.297  0.148  -28.0
# 24   김헌곤    2020       RF   32  283  0.248  0.312  0.315  0.627  0.295   67.3
# 25   박승규    2020       RF   20  196  0.258  0.297  0.335  0.632  0.288   63.0
# 26    팔카    2020       DH   29  217  0.209  0.272  0.367  0.639  0.288   59.6
# 27   박계범    2020       SS   24  175  0.195  0.227  0.293  0.519  0.233   25.6
# 28   이성규    2020       1B   27  245  0.181  0.257  0.361  0.618  0.274   50.1

# %%
ruf = df[df.Name == '러프'][columns]
ruf.reset_index(drop=True, inplace=True)

# 러프 최악의 성적만 뽑음
ruf = ruf.apply(min)
ruf
# Out:
# Name           러프
# Season       2017
# Position       1B
# Age            31
# PA            568
# AVG         0.292
# OBP         0.396
# SLG         0.515
# OPS         0.911
# wOBA        0.406
# WRC+        142.6
# dtype: object

# %%
weak = pd.DataFrame()
player = ['이원석', '이성규', '김호재', '이성곤', '박계범', '살라디노', '팔카']
for p in player:
    weak = pd.concat([weak, samsung[samsung.Name == p]])

weak = weak.drop(['Season'], axis=1).reset_index(drop=True)
weak
# Out:
#    Name Position  Age   PA    AVG    OBP    SLG    OPS   wOBA   WRC+
# 0   이원석       3B   34  467  0.268  0.341  0.407  0.748  0.338   93.7
# 1   이성규       1B   27  245  0.181  0.257  0.361  0.618  0.274   50.1
# 2   김호재       3B   25  138  0.322  0.416  0.390  0.806  0.381  124.0
# 3   이성곤       1B   28  154  0.281  0.329  0.439  0.768  0.340   94.5
# 4   박계범       SS   24  175  0.195  0.227  0.293  0.519  0.233   25.6
# 5  살라디노       LF   31  163  0.280  0.411  0.477  0.888  0.405  136.3
# 6    팔카       DH   29  217  0.209  0.272  0.367  0.639  0.288   59.6

# %%
def compare_with_ruf(df, records, figsize = [10, 30]):
    plt.rcParams['figure.figsize'] = figsize

    for idx, record in enumerate(records):
        plt.subplot(len(records), 1, idx+1)
        plt.bar(weak.Name, weak[record], width=0.5)
        plt.title(record, fontsize=15)
        plt.axhline(y=ruf[record], color='r', linewidth=2)
        plt.show()

# %%
compare_with_ruf(weak, ['AVG', 'OBP', 'SLG', 'OPS', 'wOBA', 'WRC+'])

# %%
3년간 중심타선을 책임진 러프의 재계약 불발 이후, 올해 그 빈자리를 주로 맡은 선수는 이원석, 이성규, 살라디노, 팔카임.

그 중 살라디노는 부상으로 시즌 중반 아웃되어 무의미해졌고, 이원석은 그럭저럭 선방은 했으나 원래 포지션 외에 러프 역할까지
대체하기를 바라는것은 무리였음. 그렇다면 대놓고 기회를 부여받은 이성규와 대체 용병 팔카가 활약을 보여주었어야 했는데,
이 둘은 러프가 남긴 기록의 최소값들과 비교했음에도, 상당한 차이가 날 정도로 처참한 성적을 남겼음.

# %%
# 에이징 커브 알아보기

# %%
name = set(df.Name)
aging_df = pd.DataFrame()

for n in name:
    active = df[df.Name == n].Season
    if len(active) > 8:
        aging_df = pd.concat([aging_df, df[df.Name == n]], ignore_index=True)
        
aging_df = aging_df[aging_df.PA > 100]
aging_df
# Out:
#      Name  Season      Birth Team Position   WAR    G   PA   AB   R  ...  DP  \
# 0     홍성흔    1999 1977-02-28    두        C  1.72  111  392  353  47  ...  10
# 1     홍성흔    2000 1977-02-28    두        C  2.96  127  484  438  55  ...  12
# 2     홍성흔    2001 1977-02-28    두        C  1.72  122  452  408  50  ...  13
# 3     홍성흔    2002 1977-02-28    두        C  4.18  127  484  432  51  ...  17
# 4     홍성흔    2003 1977-02-28    두        C  1.65   73  263  241  20  ...   8
# ...   ...     ...        ...  ...      ...   ...  ...  ...  ...  ..  ...  ..
# 3791  채종국    2004 1975-10-24    현       2B  1.31  128  385  327  40  ...   6
# 3792  채종국    2005 1975-10-24    현       2B  0.76  106  407  342  45  ...   6
# 3793  채종국    2006 1975-10-24    현       2B -0.28   97  257  222  25  ...   7
# 3805  황윤성    2003 1974-03-14   현K       1B -0.44   64  117   95   5  ...   2
# 3807  황윤성    2005 1974-03-14    두       1B  0.39   55  137  119  16  ...   3
#
#       SH  SF    AVG    OBP    SLG    OPS   wOBA   WRC+  Age
# 0     10   4  0.258  0.304  0.439  0.743  0.314   78.8   22
# 1      7   4  0.290  0.340  0.397  0.737  0.328   91.0   23
# 2      8   4  0.267  0.318  0.375  0.693  0.311   73.5   24
# 3      7   3  0.289  0.350  0.454  0.804  0.351  115.9   25
# 4      2   5  0.290  0.326  0.427  0.753  0.334   97.4   26
# ...   ..  ..    ...    ...    ...    ...    ...    ...  ...
# 3791  21   1  0.275  0.346  0.370  0.716  0.319   86.3   29
# 3792  16   5  0.237  0.320  0.351  0.671  0.301   78.6   30
# 3793  14   2  0.212  0.272  0.279  0.551  0.249   49.1   31
# 3805   4   1  0.179  0.301  0.263  0.564  0.265   49.6   29
# 3807   0   0  0.244  0.343  0.370  0.713  0.335  101.5   31
#
# [2988 rows x 32 columns]

# %%
aging_df.Age.describe()
# Out:
# count    2988.000000
# mean       28.919679
# std         4.383626
# min        18.000000
# 25%        26.000000
# 50%        29.000000
# 75%        32.000000
# max        41.000000
# Name: Age, dtype: float64

# %%
aging_df.groupby(aging_df.Age).nunique().Name
# Out:
# Age
# 18      1
# 19     28
# 20     45
# 21     45
# 22     73
# 23    142
# 24    179
# 25    189
# 26    213
# 27    228
# 28    230
# 29    241
# 30    237
# 31    229
# 32    201
# 33    179
# 34    148
# 35    113
# 36     80
# 37     53
# 38     37
# 39     18
# 40     10
# 41      8
# Name: Name, dtype: int64

# %%
aging_df[(aging_df.Age == 18) | (aging_df.Age > 38)].head()
# Out:
#     Name  Season      Birth Team Position   WAR    G   PA   AB   R  ...  DP  \
# 78   유한준    2020 1981-07-01    K       DH  0.65  119  428  386  48  ...   9
# 200  박진만    2015 1976-11-30    S       3B  0.48   78  162  133  12  ...   3
# 259  이병규    2013 1974-10-25    L       RF  2.92   98  401  374  39  ...  10
# 262  이병규    2014 1974-10-25    L       DH -0.72   62  207  195  23  ...   5
# 264  이병규    2015 1974-10-25    L       DH -0.47   54  102   96   3  ...   4
#
#      SH  SF    AVG    OBP    SLG    OPS   wOBA   WRC+  Age
# 78    1   1  0.280  0.347  0.409  0.756  0.345   99.3   39
# 200   2   0  0.248  0.375  0.331  0.706  0.333   92.5   39
# 259   0   3  0.348  0.384  0.455  0.839  0.389  132.7   39
# 262   2   0  0.251  0.288  0.313  0.601  0.277   50.3   40
# 264   0   1  0.219  0.255  0.323  0.578  0.261   44.9   41
#
# [5 rows x 32 columns]

# %%
aging_df.drop(aging_df[(aging_df.Age == 18) | (aging_df.Age > 38)].index, axis=0, inplace=True)
aging_df.head()
# Out:
#   Name  Season      Birth Team Position   WAR    G   PA   AB   R  ...  DP  SH  \
# 0  홍성흔    1999 1977-02-28    두        C  1.72  111  392  353  47  ...  10  10
# 1  홍성흔    2000 1977-02-28    두        C  2.96  127  484  438  55  ...  12   7
# 2  홍성흔    2001 1977-02-28    두        C  1.72  122  452  408  50  ...  13   8
# 3  홍성흔    2002 1977-02-28    두        C  4.18  127  484  432  51  ...  17   7
# 4  홍성흔    2003 1977-02-28    두        C  1.65   73  263  241  20  ...   8   2
#
#    SF    AVG    OBP    SLG    OPS   wOBA   WRC+  Age
# 0   4  0.258  0.304  0.439  0.743  0.314   78.8   22
# 1   4  0.290  0.340  0.397  0.737  0.328   91.0   23
# 2   4  0.267  0.318  0.375  0.693  0.311   73.5   24
# 3   3  0.289  0.350  0.454  0.804  0.351  115.9   25
# 4   5  0.290  0.326  0.427  0.753  0.334   97.4   26
#
# [5 rows x 32 columns]

# %%
group_df = aging_df.groupby(aging_df.Age).mean().round(3).drop('Season', axis=1)
group_df.reset_index(inplace=True)
group_df.head()
# Out:
#    Age    WAR        G       PA       AB       R       H      2B     3B  \
# 0   19  1.191   88.036  269.500  236.964  33.250  61.679  11.429  1.607
# 1   20  1.648   94.956  311.822  273.244  38.044  74.000  13.089  1.978
# 2   21  1.791  101.222  340.178  297.067  41.800  80.600  13.756  2.022
# 3   22  2.010   97.904  341.877  297.082  43.164  79.712  13.986  1.740
# 4   23  2.038  100.594  338.259  294.252  41.832  79.021  14.385  2.070
#
#       HR  ...      SO     DP     SH     SF    AVG    OBP    SLG    OPS   wOBA  \
# 0  5.464  ...  48.071  4.893  4.071  1.893  0.256  0.328  0.380  0.708  0.323
# 1  5.556  ...  52.444  5.133  5.511  2.156  0.265  0.334  0.386  0.719  0.327
# 2  6.578  ...  51.089  5.778  6.844  2.000  0.261  0.329  0.380  0.709  0.321
# 3  8.192  ...  49.877  6.370  5.589  3.384  0.259  0.330  0.389  0.720  0.326
# 4  7.322  ...  49.350  5.804  6.350  2.524  0.259  0.331  0.384  0.716  0.325
#
#      WRC+
# 0  92.118
# 1  97.984
# 2  93.020
# 3  97.815
# 4  97.419
#
# [5 rows x 27 columns]

# %%
# to plot multiple graphs

def multi_graph(df, records, up, down, figsize = [15, 20]):
    plt.rcParams['figure.figsize'] = figsize
    minx = min(df.Age)
    maxx = max(df.Age)

    for idx, record in enumerate(records):
        plt.subplot(len(records), 1, idx+1)
        plt.plot(df.Age, df[record])
        plt.title(record, fontsize=15)
        plt.fill([minx, minx, maxx, maxx], [down[record], up[record], up[record], down[record]], color='lightgray', alpha=0.7)
        plt.axvline(x=33, color='r', linewidth=1)
        plt.xticks(df.Age)
        plt.show()

# %%
up = {'AVG': 0.270, 'OBP': 0.345, 'SLG': 0.395, 'OPS': 0.74, 'WRC+': 100}
down = {'AVG': 0.2675, 'OBP': 0.340, 'SLG': 0.390, 'OPS': 0.73, 'WRC+': 98}
records = ['AVG', 'OBP', 'SLG', 'OPS', 'WRC+']

multi_graph(group_df, records, up, down)

# %%
위 그래프들을 봤을때 33세에서 급격한 타격지표 저하가 나타남.

특히 타자의 득점 생산성을 나타내는 지표인 WRC+를 보면, 전성기를 지나온 선수가 리그 평균 WRC+ 기준인 100을 이탈하는 순간이 33세임.
즉, 타자의 에이징 커브는 33세를 기점으로 시작된다고 볼 수 있음.

# %%
# 포지션별

# %%
check = aging_df[aging_df.Position == '1B']
check.groupby(check.Age).nunique().Name
# Out:
# Age
# 19     5
# 20     8
# 21     7
# 22    10
# 23    14
# 24    24
# 25    23
# 26    24
# 27    30
# 28    31
# 29    33
# 30    23
# 31    25
# 32    25
# 33    26
# 34    23
# 35    15
# 36    18
# 37    11
# 38     7
# Name: Name, dtype: int64

# %%
pos_df = aging_df.groupby([aging_df.Position, aging_df.Age]).mean().round(3).drop('Season', axis=1)
b1 = pos_df.query("Position == '1B'")
b1.reset_index(inplace=True)
b1 = b1.drop(b1[b1['Age'] <20].index)

b1
# Out:
#    Position  Age    WAR        G       PA       AB       R        H      2B  \
# 1        1B   20  0.870   83.625  264.750  237.000  28.500   63.875  12.250
# 2        1B   21  2.643   93.143  370.571  326.429  46.857   98.429  18.429
# 3        1B   22  2.108   95.000  363.000  313.800  44.600   85.600  17.000
# 4        1B   23  2.766  103.286  373.571  317.429  55.929   92.214  18.000
# 5        1B   24  2.349   96.417  348.750  301.667  45.625   84.958  16.792
# 6        1B   25  2.464   94.043  350.261  300.174  43.913   85.391  14.565
# 7        1B   26  2.551  101.792  377.333  328.292  46.750   92.333  18.750
# 8        1B   27  2.590   96.800  354.500  307.133  46.333   90.000  16.033
# 9        1B   28  2.021  100.194  360.065  313.742  46.323   88.452  15.774
# 10       1B   29  2.254   99.394  354.727  304.424  45.091   86.667  15.909
# 11       1B   30  2.271  105.696  396.913  346.000  48.957  100.739  17.522
# 12       1B   31  1.798  102.800  370.640  323.800  45.520   91.160  17.120
# 13       1B   32  1.721   97.760  344.480  297.720  42.640   84.360  15.000
# 14       1B   33  1.523  107.923  364.077  318.423  44.077   88.462  17.269
# 15       1B   34  0.985   97.783  323.348  283.565  36.609   77.652  13.609
# 16       1B   35  1.725  109.000  405.333  352.933  46.267   99.733  16.467
# 17       1B   36  1.217   98.167  342.889  302.778  38.389   84.278  15.611
# 18       1B   37  0.629   96.000  317.636  282.273  30.364   76.091  12.000
# 19       1B   38  0.670   91.571  309.286  271.143  30.429   76.143  14.000
#
#        3B  ...      SO     DP     SH     SF    AVG    OBP    SLG    OPS  \
# 1   1.750  ...  48.250  5.875  1.875  1.875  0.253  0.325  0.384  0.709
# 2   1.857  ...  54.857  6.857  3.429  1.714  0.286  0.359  0.462  0.820
# 3   0.900  ...  54.500  7.700  2.200  3.400  0.256  0.334  0.426  0.759
# 4   1.857  ...  57.929  6.214  2.500  3.071  0.268  0.353  0.431  0.783
# 5   1.792  ...  50.167  6.833  1.833  2.750  0.270  0.352  0.434  0.786
# 6   1.739  ...  48.696  7.609  1.261  2.826  0.276  0.364  0.431  0.795
# 7   2.250  ...  53.417  6.042  2.292  2.917  0.272  0.350  0.442  0.792
# 8   1.100  ...  53.233  6.267  1.567  2.733  0.285  0.367  0.472  0.839
# 9   1.484  ...  52.452  6.710  2.129  2.613  0.274  0.355  0.431  0.785
# 10  1.455  ...  50.121  7.152  2.576  2.909  0.274  0.364  0.436  0.800
# 11  1.609  ...  50.913  7.957  3.043  3.217  0.285  0.364  0.437  0.801
# 12  1.240  ...  53.600  8.480  1.880  3.080  0.278  0.355  0.421  0.776
# 13  0.840  ...  55.840  7.240  1.920  3.280  0.271  0.360  0.424  0.783
# 14  0.885  ...  59.231  8.577  2.577  3.423  0.272  0.346  0.424  0.770
# 15  0.652  ...  53.304  6.522  2.174  2.696  0.268  0.343  0.388  0.731
# 16  0.733  ...  61.667  9.933  2.600  3.067  0.276  0.352  0.417  0.769
# 17  0.667  ...  51.833  8.111  2.056  2.833  0.268  0.341  0.397  0.738
# 18  0.545  ...  48.455  8.636  2.364  3.909  0.262  0.330  0.385  0.716
# 19  0.571  ...  46.571  8.286  1.714  3.286  0.276  0.353  0.384  0.738
#
#      wOBA     WRC+
# 1   0.324   94.738
# 2   0.363  121.600
# 3   0.343  108.960
# 4   0.350  111.679
# 5   0.356  120.200
# 6   0.363  125.383
# 7   0.357  122.721
# 8   0.375  129.180
# 9   0.355  115.455
# 10  0.362  121.042
# 11  0.365  121.317
# 12  0.352  112.632
# 13  0.354  109.948
# 14  0.345  105.912
# 15  0.334   97.496
# 16  0.348  109.347
# 17  0.338  101.594
# 18  0.325   92.445
# 19  0.336   95.157
#
# [19 rows x 28 columns]

# %%
check = aging_df[aging_df.Position == '3B']
check.groupby(check.Age).nunique().Name
# Out:
# Age
# 19     3
# 20     4
# 21     7
# 22    12
# 23    29
# 24    32
# 25    24
# 26    32
# 27    39
# 28    31
# 29    29
# 30    22
# 31    27
# 32    22
# 33    21
# 34     7
# 35     8
# 36     8
# 37     5
# Name: Name, dtype: int64

# %%
pos_df = aging_df.groupby([aging_df.Position, aging_df.Age]).mean().round(3).drop('Season', axis=1)
b3 = pos_df.query("Position == '3B'")
b3.reset_index(inplace=True)
b3 = b3.drop(b3[(b3['Age'] < 21) | (b3['Age'] > 36)].index)

b3
# Out:
#    Position  Age    WAR        G       PA       AB       R        H      2B  \
# 2        3B   21  1.731   92.857  294.857  258.000  35.286   70.000  13.143
# 3        3B   22  2.174   99.167  355.000  312.333  44.750   82.833  14.667
# 4        3B   23  2.206   96.793  338.966  295.931  40.241   80.241  15.448
# 5        3B   24  2.196   94.031  321.781  279.531  39.250   76.344  13.500
# 6        3B   25  2.439   97.542  355.167  307.417  41.167   83.083  15.042
# 7        3B   26  2.548  102.438  377.625  326.594  45.219   89.812  16.125
# 8        3B   27  2.389   99.000  356.256  308.359  44.769   85.282  16.077
# 9        3B   28  2.487  100.419  367.290  319.419  45.613   88.935  16.548
# 10       3B   29  2.186  102.828  373.345  324.759  47.828   89.552  15.793
# 11       3B   30  2.448  105.227  375.409  323.136  46.909   92.182  16.409
# 12       3B   31  1.967  100.926  364.778  317.704  44.296   86.370  15.148
# 13       3B   32  2.094  103.864  364.227  312.364  43.545   82.909  15.364
# 14       3B   33  2.086   98.095  337.524  292.381  42.619   81.905  15.476
# 15       3B   34  2.240  117.714  433.429  376.143  49.000  104.571  18.429
# 16       3B   35  1.672  109.250  358.250  311.625  42.625   85.625  14.250
# 17       3B   36  1.274   89.250  299.875  264.625  30.625   69.875  11.000
#
#        3B  ...      SO      DP     SH     SF    AVG    OBP    SLG    OPS  \
# 2   0.857  ...  42.286   5.857  6.143  2.000  0.266  0.322  0.383  0.705
# 3   1.333  ...  55.083   7.167  4.083  3.667  0.261  0.327  0.417  0.744
# 4   1.483  ...  53.517   6.552  6.828  2.517  0.261  0.332  0.397  0.729
# 5   1.562  ...  44.406   6.844  5.688  2.500  0.260  0.336  0.390  0.726
# 6   1.292  ...  50.875   8.292  5.833  2.750  0.262  0.339  0.397  0.736
# 7   1.344  ...  52.125   8.438  5.812  3.125  0.269  0.346  0.409  0.755
# 8   1.462  ...  49.846   8.256  5.872  3.103  0.270  0.349  0.412  0.761
# 9   1.516  ...  53.806   8.516  4.323  2.935  0.267  0.344  0.415  0.760
# 10  1.172  ...  53.931   7.966  3.828  3.276  0.266  0.344  0.406  0.750
# 11  0.955  ...  55.864   8.136  4.545  3.955  0.276  0.356  0.430  0.785
# 12  1.074  ...  57.185   8.407  5.519  2.852  0.268  0.343  0.407  0.751
# 13  0.864  ...  57.045   8.409  4.955  3.591  0.253  0.336  0.391  0.727
# 14  0.905  ...  54.095   9.238  3.810  2.952  0.273  0.355  0.428  0.783
# 15  0.571  ...  71.857  10.571  5.143  4.714  0.275  0.351  0.427  0.779
# 16  0.250  ...  59.125   9.000  5.500  3.125  0.266  0.339  0.398  0.737
# 17  0.000  ...  46.625   9.625  2.875  3.375  0.259  0.329  0.380  0.710
#
#      wOBA     WRC+
# 2   0.315   88.086
# 3   0.334  103.283
# 4   0.329  100.262
# 5   0.329   99.831
# 6   0.335  105.262
# 7   0.342  107.778
# 8   0.345  107.941
# 9   0.342  103.542
# 10  0.338   98.703
# 11  0.350  106.923
# 12  0.337   99.541
# 13  0.329   95.850
# 14  0.351  106.710
# 15  0.348  105.514
# 16  0.330   95.262
# 17  0.323   93.125
#
# [16 rows x 28 columns]

# %%
multi_graph(b1, ['WRC+'], {'WRC+':115}, {'WRC+': 120}, [15, 7])
multi_graph(b3, ['WRC+'], {'WRC+':100}, {'WRC+': 102.5}, [15, 7])

# %%
1루수는 포지션 특성상 수비보다는 타격에 좀 더 중점을 두는 경향이 있음.

그렇기에 1루수의 WRC+는 120 이상의 높은 생산성을 가진 타자들로 구성되어 있음. 하지만, 1루수들 역시 에이징 커브가 본격적으로 시작되는 
33세 부터 WRC+가 리그 평균인 100으로 회귀하며 35세 때의 약간의 반등을 제외하고는 생산성이 급격히 추락하는 모습을 보임.

# %%
plt.figure(figsize=(15, 7))
oh = aging_df[aging_df.Name ==  '오재일']
lee = aging_df[aging_df.Name ==  '이원석']
heo = aging_df[aging_df.Name ==  '허경민']

plt.plot(oh.Age, oh['WRC+'], label='오재일')
plt.plot(lee.Age, lee['WRC+'], label='이원석')
plt.plot(heo.Age, heo['WRC+'], label='허경민')

plt.axhline(y=100, color='lightgray', linewidth=2)
plt.xticks(list(oh.Age.unique())+list(lee.Age.unique()))
plt.yticks([50, 60, 70, 80, 90, 100, 120, 140, 160])

plt.legend()
plt.show()

# %%
def compare_two(df1, df2, records, line, label, figsize = [15, 20]):
    plt.rcParams['figure.figsize'] = figsize

    for idx, record in enumerate(records):
        plt.subplot(len(records), 1, idx+1)
        plt.plot(df1.Age, df1[record], label=label[0])
        plt.plot(df1.Age, df2[record], label=label[1])
        plt.axhline(y=line[record], color='lightgray', linewidth=2)
        plt.title(record, fontsize=15)
        plt.xticks(df1.Age)
        plt.legend()
        plt.show()

# %%
oh = aging_df[(aging_df.Name ==  '오재일') & (aging_df.Age > 30)]
lee = aging_df[(aging_df.Name ==  '이원석') & (aging_df.Age > 30)]
line = {'AVG': 0.3, 'OBP':0.35, 'SLG': 0.5, 'OPS': 0.9, 'WRC+':120}

compare_two(oh, lee, ['AVG', 'OBP', 'SLG', 'OPS', 'WRC+'], line, ['오재일', '이원석'])

# %%
오재일, 이원석을 비교해 보면, 이원석은 1루수의 에이징 커브 시작점인 32세를 기점으로 WRC+ 지표가 꾸준히 하락하고 있으나
오재일은 반등에 성공하며 꾸준한 생산능력을 보이고 있음.

# %%
plt.figure(figsize=(15, 7))
yoo = aging_df[aging_df.Name ==  '유한준']
plt.plot(yoo.Age, yoo['WRC+'])
plt.axhline(y=100, color='lightgray', linewidth=2)
plt.xticks(yoo.Age)
plt.yticks([50, 60, 70, 80, 90, 100, 120, 140, 160])
plt.show()

# %%
긍정적으로 보았을 때, 오재일이 이원석 보다 늦게 포텐이 터졌고 일반적으로 타자의 에이징 커브가 시작되는 33세 이후에도
리그 중상급의 생산성을 보이고 있다는 점, 이와 비슷한 케이스로 유한준의 모델을 따른다고 생각하면 FA로서의 가치는 충분하다고 보여짐

# %%
#FA

# %%
fa = ['오재일', '최주환', '허경민', '최형우']
fa_df = pd.DataFrame()

for f in fa:
    fa_df = pd.concat([fa_df, df[(df.Name == f) & (df.Season == 2020)][columns]])

fa_df.reset_index(inplace=True, drop=True)
fa_df
# Out:
#   Name  Season Position  Age    AVG    OBP    SLG    OPS   wOBA   WRC+
# 0  오재일    2020       1B   34  0.312  0.390  0.482  0.872  0.394  138.9
# 1  최주환    2020       2B   32  0.305  0.365  0.472  0.838  0.372  123.7
# 2  허경민    2020       3B   30  0.332  0.382  0.442  0.824  0.373  122.7
# 3  최형우    2020       DH   37  0.354  0.433  0.590  1.023  0.450  168.4
